# %%
import pandas as pd

# %%
train = pd.read_csv('train.csv')

# %%
groups = train.groupby('Hardness')

# Sampling 10% from each group
val_indices = groups.apply(lambda x: x.sample(frac=0.1, random_state=5)).index.get_level_values(1)
train_indices = train.index.difference(val_indices)

new_train = train.loc[train_indices].drop('id', axis=1)
# y_train = y.loc[train_indices]
new_val = train.loc[val_indices].drop('id', axis=1)
# y_val = y.loc[val_indices]

new_train.shape, new_val.shape
# Out:
# ((9368, 12), (1039, 12))

# %%
new_train.describe([0.01, 0.25, 0.5, 0.75, 0.99]).T
# Out:
#                         count        mean         std  min        1%  \
# allelectrons_Total     9368.0  128.725309  233.490676  0.0  6.000000
# density_Total          9368.0   14.533354   16.111258  0.0  0.738864
# allelectrons_Average   9368.0   17.024454   10.417438  0.0  4.666667
# val_e_Average          9368.0    4.548118    0.692676  0.0  2.000000
# atomicweight_Average   9368.0   37.472404   25.869733  0.0  8.773227
# ionenergy_Average      9368.0   10.937861    1.408934  0.0  8.099566
# el_neg_chi_Average     9368.0    2.607057    0.335751  0.0  1.790000
# R_vdw_element_Average  9368.0    1.731814    0.192123  0.0  1.318667
# R_cov_element_Average  9368.0    0.944041    0.179848  0.0  0.505333
# zaratio_Average        9368.0    0.493107    0.062980  0.0  0.403380
# density_Average        9368.0    2.135703    1.935556  0.0  0.133484
# Hardness               9368.0    4.647074    1.680963  1.0  1.500000
#
# ...

# %%
new_val.describe([0.01, 0.25, 0.5, 0.75, 0.99]).T
# Out:
#                         count        mean         std  min        1%  \
# allelectrons_Total     1039.0  121.996381  107.507991  0.0  6.000000
# density_Total          1039.0   14.112543   14.668113  0.0  0.774646
# allelectrons_Average   1039.0   17.112277   10.925253  0.0  4.666667
# val_e_Average          1039.0    4.534807    0.674509  0.0  2.253333
# atomicweight_Average   1039.0   37.825967   27.275151  0.0  8.808713
# ionenergy_Average      1039.0   10.942339    1.402996  0.0  8.054000
# el_neg_chi_Average     1039.0    2.613117    0.327294  0.0  1.790000
# R_vdw_element_Average  1039.0    1.726966    0.195721  0.0  1.318667
# R_cov_element_Average  1039.0    0.944958    0.181614  0.0  0.512596
# zaratio_Average        1039.0    0.495529    0.063963  0.0  0.420492
# density_Average        1039.0    2.108464    1.947308  0.0  0.122476
# Hardness               1039.0    4.647594    1.677380  1.3  1.500000
#
# ...

# %%
new_train.head()
# Out:
#    allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 0               100.0       0.841611                  10.0            4.8
# 1               100.0       7.558488                  10.0            4.8
# 2                76.0       8.885992                  15.6            5.6
# 3               100.0       8.795296                  10.0            4.8
# 4               116.0       9.577996                  11.6            4.8
#
#    atomicweight_Average  ionenergy_Average  el_neg_chi_Average  \
# 0             20.612526           11.08810               2.766
# 1             20.298893           12.04083               2.755
# 2             33.739258           12.08630               2.828
# 3             20.213349           10.94850               2.648
# 4             24.988133           11.82448               2.766
#
#    R_vdw_element_Average  R_cov_element_Average  zaratio_Average  \
# 0                  1.732                  0.860         0.496070
# ...

# %%
new_val.head()
# Out:
#       allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 2359               183.0      31.800000             61.000000       4.333333
# 1114                74.0       9.509324             24.666667       4.333333
# 7904               100.0       7.558488             10.000000       4.800000
# 1532                92.0      10.650000             31.000000       4.000000
# 9549                33.0       1.740168              6.000000       3.100000
#
#       atomicweight_Average  ionenergy_Average  el_neg_chi_Average  \
# 2359            150.722190           8.054000            1.986667
# 1114             53.356000           9.270800            2.440000
# 7904             20.298893          12.040830            2.755000
# 1532             69.592128           9.152733            2.225000
# 9549             11.663548          12.415840            2.518000
#
#       R_vdw_element_Average  R_cov_element_Average  zaratio_Average  \
# ...

# %%
new_train.to_csv('training_data.csv', index=False)

# %%
new_val.to_csv('validation_data.csv', index=False)
